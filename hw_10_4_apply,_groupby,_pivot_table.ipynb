# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd

# %%
data_path = '../data/supermarket_sales.csv'
df = pd.read_csv(data_path)

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
df.groupby('Branch')['gross income'].agg(["sum"])
# Out:
#               sum
# Branch
# A       5057.1605
# B       5057.0320
# C       5265.1765

# %% [markdown]
# Найбільш прибутковою є філія С (Naypyitaw). Філії А та В мають приблизно однаковий показник сумарногоприбутку.

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
df.sort_values(by="gross income", ascending=False).head(1)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 350        99.3        10   49.65  1042.65  2/15/2019  14:53  Credit card
#
#       cogs  gross margin percentage  gross income  Rating
# 350  993.0                 4.761905         49.65     6.6

# %% [markdown]
# Найвищий прибуток зафіксовано в місті Naypyitaw, сумарний прибуток там також найвищий. В попередньому дослідженні ми виявили, що в цьому місті і середній чек більший, і одночасно кількість покупців менша. Однак, розміщення ще одного магазину є перспективним лише після оцінки загальної кількості мешканців (ємність ринку), а також роботи конкурентів. Можливо, замість нового магазину потрібно залучити більше покупців з цільового сегменту (це можуть бути жінки і продукти з категорії Fashion accessories).

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
df.rename(columns={'Product line' : 'product_line'}, inplace=True)

# %%
invoices_by_category = pd.pivot_table(df, index='Branch', columns='product_line', values='Invoice ID', aggfunc='count')

# %%
invoices_by_category
# Out:
# product_line  Electronic accessories  Fashion accessories  Food and beverages  \
# Branch
# A                                 60                   51                  58
# B                                 55                   62                  50
# C                                 55                   65                  66
#
# product_line  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                            47                  65                 59
# B                            53                  50                 62
# C                            52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
max_branch = invoices_by_category['Electronic accessories'].idxmax()
max_value = invoices_by_category['Electronic accessories'].max()

max_branch, max_value
# Out:
# ('A', 60)

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %% [markdown]
# Гіпотеза 1: Найбільше прибутку приносять постійні покупці
# Гіпотеза 2: Найбільше прибутку приносять покупці - жінки
# Гіпотеза 3: Найбільші прибутки формуються наприкінці місяця

# %% [markdown]
# Перевірка гіпотези 1:

# %%
df.groupby('Customer type')['gross income'].agg(["mean"])
# Out:
#                     mean
# Customer type
# Member         15.609110
# Normal         15.148707

# %%
df.groupby('Customer type')['gross income'].agg(["sum"])
# Out:
#                     sum
# Customer type
# Member         7820.164
# Normal         7559.205

# %% [markdown]
# Гіпотеза 1 підтверджена: середній показник прибутку на постійного покупця більший, ніж для звичайного; аналогічно і сума прибутку більша у категорії постійних покупців. Результат такого обрахунку може мотивувати бізнес залучати більше постійних клієнтів через акції або інші інструменти, адже саме ця категорія дає потенційний приріст прибутку у майбітньому.

# %% [markdown]
# Перевірка гіпотези 2:

# %%
df.groupby('Gender')['gross income'].agg(["mean"])
# Out:
#              mean
# Gender
# Female  15.956936
# Male    14.799487

# %%
df.groupby('Gender')['gross income'].agg(["sum"])
# Out:
#              sum
# Gender
# Female  7994.425
# Male    7384.944

# %% [markdown]
# Гіпотеза 2 підтверджена: середній показник прибутку для жінок більший, ніж для чоловіків; аналогічно і сума прибутку більша для покупців-жінок. Результат такого аналізу може мотивувати бізнес залучати більше жінок, створюючи відповідну таргетовану рекламу та підсилюючі категорії товарів, які будуть цікаві жінкам.

# %% [markdown]
# Перевірка гіпотези 3:

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')

# %%
pd.pivot_table(
    df,
    values='gross income',
    index=df['Date'].dt.day,
    aggfunc='sum'
).sort_values(by='gross income', ascending=False).head(10)
# Out:
#       gross income
# Date
# 15        748.4505
# 19        708.7255
# 9         655.5850
# 14        649.3020
# 8         643.0370
# 27        638.0080
# 5         609.4615
# 2         602.2265
# 23        591.8485
# 3         590.4395

# %% [markdown]
# Гіпотеза 3 не підтверджена, тож прибуток здебільшого не формується наприкінці місяця. Для бізнесу є сенс порівняти обсяги прибутку за тижнями, а потім і за робочими днями та вихідними. Це дозволить додати більше продавців-консультантів в потрібні дні, а також спланувати дати акцій та рекламних кампаній.
